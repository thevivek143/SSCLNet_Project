# %% [markdown]
# # SSCLNet Knee OA Training Notebook
#
# This notebook detects the GPU, installs dependencies, loads the project, and runs the training loop for the Knee Osteoarthritis pipeline.

# %% [markdown]
# ## 1. Check GPU Status

# %%
# !nvidia-smi

# %% [markdown]
# ## 2. Upload Project ZIP
# Upload the `SSCLNet_Project.zip` file containing the code and dataset.

# %%
from google.colab import files
uploaded = files.upload()

# %% [markdown]
# ## 3. Unzip Project
# Extract the project steps and verify structure.

# %%
# !unzip -q SSCLNet_Project.zip
# !ls -d SSCLNet_Project/

# %% [markdown]
# ## 4. Install Dependencies

# %%
# !pip install timm albumentations opencv-python tqdm

# %% [markdown]
# ## 5. Verify Dataset

# %%
# !ls SSCLNet_Project/datasets/kneeoa/train
# !ls SSCLNet_Project/datasets/kneeoa/test

# %% [markdown]
# ## 6. Setup Training Directory

# %%
# %cd SSCLNet_Project/knee

# %% [markdown]
# ## 7. Verify Configuration (Batch Size)

# %%
# !grep "BATCH_SIZE" train_knee_classifier.py

# %% [markdown]
# ## 8. Train Model

# %%
# !python train_knee_classifier.py

# %% [markdown]
# ## 9. Download Best Model

# %%
from google.colab import files
if os.path.exists('models/best_knee_model.pth'):
    files.download('models/best_knee_model.pth')
else:
    print("Model file not found!")
